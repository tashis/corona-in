# %% [markdown]
# # Corona Virus numbers by Indian State
# > An attempt to capture and share data on this formidable Corona Virus
#
# - toc: true
# - badges: true
# - comments: true
# - categories: [jupyter]
# - image: images/chart-preview.png

# %%
#hide    
def draw_plot_alt(graph_df,num_days,title):
    import altair as alt
    graph_df
    #wb_df=graph_df.query("detected_state == '{0}'".format(title)).reset_index()
    #wb_df=wb_df[["diagnosed_date",0]]
    #wb_df.rename(columns={0:'Cases'},inplace=True)
    #wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
    #wb_df
    #alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    #    alt.X('diagnosed_date', title='date'),
    #    alt.Y('sum(Cases)', title='cases')
    #).interactive()
    return

def draw_plot(graph_df,num_days,title):
    wb_df=graph_df.query("detected_state == '{0}'".format(title)).reset_index()
    wb_df=wb_df[["diagnosed_date",0]]
    df = wb_df.set_index(wb_df['diagnosed_date'])
    from datetime import date, timedelta
    dt = date.today() - timedelta(days=num_days)
    df=df.loc[dt:date.today()]
    p1=plt.bar(df['diagnosed_date'],df[0])
    plt.plot(df['diagnosed_date'],df[0])
    plt.ylabel('Number of Cases')
    plt.xlabel(title)
    plt.show()
    return
    

def get_states():
    states = [
    "Andhra Pradesh",
    "Arunachal Pradesh",
    "Assam",
    "Bihar",
    "Chhattisgarh",
    "Goa",
    "Gujarat",
    "Haryana",
    "Himachal Pradesh",
    "Jharkhand",
    "Karantaka",
    "Kerala",
    "Madhya Pradesh",
    "Maharashtra",
    "Manipur",
    "Meghalaya",
    "Mizoram",
    "Nagaland",
    "Odisha",
    "Punjab",
    "Rajasthan",
    "Sikkim",
    "Tamil Nadu",
    "Telangana",
    "Tripura",
    "Uttarakhand",
    "Uttar Pradesh",
    "West Bengal",
    "Andaman and Nicobar Islands",
    "Chandigarh",
    "Dadra and Nagar Haveli and Daman & Diu",
    "The Government of NCT of Delhi",
    "Jammu & Kashmir",
    "Ladakh",
    "Lakshadweep",
    "Puducherry"
    ]
    return states

import pandas as pd
#import numpy as np
import matplotlib.pyplot as plt
url = ('https://raw.githubusercontent.com/tashis/corona-in/master/IndividualDetails.csv')
states_df = pd.read_csv(url)
cols_keep = ["diagnosed_date", "detected_state", "current_status"]
states_red_df = states_df[cols_keep]
states_red_df['diagnosed_date']= pd.to_datetime(states_red_df["diagnosed_date"], format="%d/%m/%Y")
#states_red_df["diagnosed_date"] = pd.to_datetime(states_red_df["diagnosed_date"], format="%d/%m/%Y")
#df_cases_total = states_red_df.groupby(["detected_state","current_status"])[states_red_df['diagnosed_date']].size().to_frame().reset_index()
df_cases_total = states_red_df.groupby(["detected_state","current_status"]).size().to_frame().reset_index()
x=df_cases_total.query('current_status=="Hospitalized"')
x=x.reset_index()
x.columns
x=x[['detected_state', 0]]
y=df_cases_total.groupby('detected_state').sum()
y.rename(columns={0:'Cases'},inplace=True)
y=y.reset_index()
z=y.set_index('detected_state').join(x.set_index('detected_state'))
z.rename(columns={0:'Hospitalized'},inplace=True)
z=z.reset_index()
z.rename(columns={'detected_state':'State'},inplace=True)
graph_df=states_red_df.groupby(["detected_state","diagnosed_date"]).size().to_frame().reset_index()
# Out:
# /Users/anandsundaram/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#hide_input
import altair as alt
from altair.expr import datum
#draw_plot_alt(graph_df,14,"West Bengal")
wb_df=graph_df.reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='India'),
    alt.Y('sum(Cases)', title='Number of Cases per day')
).interactive()

base = alt.Chart(wb_df).encode(
    x='diagnosed_date:T',
    y='Cases:Q'
)

base.mark_line() + base.mark_point()
#wb_df
# Out:
# alt.LayerChart(...)

# %%
#hide_input
import altair as alt
#draw_plot_alt(graph_df,14,"West Bengal")
wb_df=graph_df.query("detected_state == 'Andhra Pradesh'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Andhra Pradesh'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Arunachal Pradesh'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Arunachal Pradesh'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Assam'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Assam'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Bihar'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Bihar'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Chhattisgarh'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Chhattisgarh'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Goa'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Goa'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Gujarat'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Gujarat'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Haryana'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Haryana'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Himachal Pradesh'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Himachal Pradesh'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Jharkhand'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Jharkhand'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Karnataka'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Karnataka'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Kerala'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Kerala'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Ladakh'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Ladakh'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Madhya Pradesh'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Madhya Pradesh'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Maharashtra'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Maharashtra'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Manipur'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Manipur'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Meghalaya'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Meghalaya'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Mizoram'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Mizoram'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Nagaland'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Nagaland'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Odisha'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Odisha'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Punjab'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Punjab'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Rajasthan'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Rajasthan'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Sikkim'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Sikkim'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Tamil Nadu'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Tamil Nadu'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Telangana'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Telangana'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Tripura'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Tripura'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Uttarakhand'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Uttarakhand'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'Uttar Pradesh'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='Uttar Pradesh'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()
# Out:
# alt.Chart(...)

# %%
#hide_input

wb_df=graph_df.query("detected_state == 'West Bengal'").reset_index()
wb_df=wb_df[["diagnosed_date",0]]
wb_df.rename(columns={0:'Cases'},inplace=True)
wb_df=wb_df.groupby("diagnosed_date").sum().reset_index()
#wb_df
alt.Chart(wb_df).mark_bar(color='firebrick').encode(
    alt.X('diagnosed_date', title='West Bengal'),
    alt.Y('sum(Cases)', title='Cases')
).interactive()


#for st in get_states():
#    draw_plot(graph_df,14,st)
# Out:
# alt.Chart(...)
